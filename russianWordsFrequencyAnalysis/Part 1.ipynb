# %% [markdown]
# # Исследование частотного словаря русского языка. Часть 1
# Это исследование проведено в процессе освоения специальности Data Analyst на [Dataquest](https://www.dataquest.io/path/data-analyst). Его цель - попрактиковаться в использовании базовых приемов программирования на Python, а заодно узнать что-нибудь интересное про русский язык.
# ## Об источнике данных
# В этой работе в качестве источника использован [Частотный словарь русского языка](http://dict.ruslang.ru/freq.php) (далее для краткости "частотный словарь"), созданный О.Н. Ляшевской и С.А. Шаровым на основе [Национального корпуса русского языка](http://www.ruscorpora.ru/en/index.html) (далее "корпус").
#
# Для начала прочитаем данные из CSV-файла, доступного для загрузки на сайте частотного словаря, и преобразуем результат в двухуровневый список.

# %%
with open('freq.txt', 'r', encoding='utf-8') as f:   
    text = f.read()
    strings =  text.split('\n')
lst = []
for string in strings:
    lst.append(string.split('\t'))
headers = lst[:1]
lst = lst[1:len(lst)]
headers
# Out:
# [['Lemma', 'PoS', 'Freq(ipm)', 'R', 'D', 'Doc']]

# %% [markdown]
# ## Вспомним части речи
# Многие из нас, окончив среднюю общеобразовательную школу, через пару лет счастливо забывают большую часть того, чему их учили на уроках русского языка. А лет через пять - десять человек не то что не может дать определение деепричастию, но даже отличие глагола от существительного с трудом назовёт - если это не филолог или лингвист, конечно.
#
# В первой части исследования мы вспомним азы русского языка (а именно части речи) и заодно посмотрим на распределение частей речи в частотном словаре.

# %%
posCount = {}
for one in lst:
    pos = one[1]
    if pos not in posCount:
        posCount[pos] = 0
    posCount[pos] +=1
posCount
# Out:
# {'a': 11573,
#  'adv': 2831,
#  'advpro': 129,
#  'anum': 31,
#  'apro': 66,
#  'conj': 84,
#  'intj': 188,
#  'num': 62,
#  'part': 182,
#  'pr': 116,
#  's': 22050,
#  's.PROP': 2418,
#  'spro': 64,
#  'v': 12344}

# %% [markdown]
# В частотном словаре части речи обозначены латинскими буквами, так что нужно их привести к удобочитаемому виду. Но сначала вспомним, какие бывают части речи:
# - существительное, отвечает на вопрос "кто?", "что?", обозначает предмет, явление, живое существо. Примеры: "человек", "книга".
# - глагол, отвечает на вопрос "что делать?", обозначает действие. Примеры: "читать", "считать".
# - прилагательное, отвечает на вопрос "какой?", обозначает свойство. Примеры: "большой", "красивый".
# - наречие, отвечает на вопрос "как?", "когда?", "где?", "почему?". Примеры: "здесь", "интересно".
# - местоимение, отвечает на вопрос "кто?", "что?", "какой?", но, в отличие от существительного или прилагательного, не называет конкретный предмет, явление, свойство, а только указывает на него. Примеры: "он", "этот", "который".
# - числительное, отвечает на вопрос "сколько?", "который (по счету)?". Примеры: "сто", "двенадцатый".
# - предлог, служебная часть речи, применяемая для соединения слов. Примеры: "из", "в".
# - союз, служебная часть речи, служащая для соединения частей предложения. Примеры: "и", "но".
# - частица, служебная часть речи, придает смысловой оттенок словам. Примеры: "-то", "-либо".
# - междометие, служебная часть речи, выражает эмоции, состояния, отношение. Примеры: "ай-ай-ай", "ого!".

# %%
ruPosNames = {
's' : 'существительное',
'v' : 'глагол',
'a' : 'прилагательное',
'adv' : 'наречие',
'advpro' : 'местоименное наречие',
'spro' : 'местоимение-существительное',
'apro' : 'местоимение-прилагательное',
'num' : 'количественное числительное',
'anum' : 'порядковое числительное',
'pr' : 'предлог',
'conj' : 'союз',
'part' : 'частица',
'intj' : 'междометие',
's.PROP' : 'имя собственное'
}

# %% [markdown]
# Можно заметить, что в словаре ruPosNames больше частей речи, чем перечислено в списке с описаниями и примерами частей речи. Это из-за того, что некоторые части речи в частотном словаре представлены двумя элементами: "наречие" - как "наречие" и "местоименое наречие", "местоимение" - как "местоимение-существительное" и "местоимение-прилагательное", "числительное" - как "количественное числительное" и "порядковое числительное", а "существительное" - как "существительное" и "имя собственное".  Авторы частотного словаря таким образом разделили некоторые части речи, а я при дальнейших подсчетах их опять объединю.

# %%
wordsTotal = len(lst)
ruPos = {}
ruPos['наречие'] = (posCount['adv'] + posCount['advpro']) / wordsTotal
ruPos['местоимение'] = (posCount['spro']+ posCount['apro']) / wordsTotal
ruPos['числительное'] = (posCount['num']+ posCount['anum']) / wordsTotal
ruPos['существительное'] = (posCount['s']+ posCount['s.PROP']) / wordsTotal
posCombined = ['adv','advpro','spro','apro','num','anum','s','s.PROP']

for pos in posCount:
    if pos not in posCombined:
        posName = ruPosNames[pos]
        ruPos[posName] = posCount[pos] / wordsTotal
ruPos
# Out:
# {'глагол': 0.23675630058690397,
#  'междометие': 0.0036058153362231,
#  'местоимение': 0.0024933829452606546,
#  'наречие': 0.05677241167670413,
#  'предлог': 0.0022248647819248916,
#  'прилагательное': 0.22196862173462734,
#  'союз': 0.0016111089800145766,
#  'существительное': 0.4692930300356746,
#  'частица': 0.0034907361233649163,
#  'числительное': 0.0017837277993018527}

# %% [markdown]
# Итак, мы видим, какую долю в словаре представляют части речи. Чтобы убедиться, что все посчитано правильно и ничего не упущено, я сложу полученные значения. В результате должна получиться единица.

# %%
sumPos = []
for key,val in ruPos.items():
    sumPos.append(val)
import math
math.fsum(sumPos)
# Out:
# 1.0

# %% [markdown]
# Отлично, получилась единица.
#
# Финальный шаг: я преобразую значения в проценты и сформирую удобочитаемый список.

# %%
for pos in ruPos:
    print (pos + ': ' + str(float('{0:.2f}'.format(ruPos[pos] *100))) + '%')
# Out:
# наречие: 5.68%
# местоимение: 0.25%
# числительное: 0.18%
# существительное: 46.93%
# союз: 0.16%
# междометие: 0.36%
# частица: 0.35%
# прилагательное: 22.2%
# глагол: 23.68%
# предлог: 0.22%

# %% [markdown]
# ### Выводы
# Почти половину частотного словаря (46.93%) составляют существительные. Значительную часть словаря составляют также глаголы (23.68%) и прилагательные (22.2%). Наименьшую часть словаря составляют союзы (0.16%), числительные (0.18%) и предлоги (0.22%).

# %% [markdown]
# ## Самые длинные и самые короткие слова русского языка
# Сколько в русскомя языке длинных слов, а сколько - коротких? Посчитаем.

# %%
lenDict = {}
for word in lst:
    lemma = word[0]
    if len(lemma) not in lenDict:
        lenDict[len(lemma)] = 0
    lenDict[len(lemma)] += 1
lenDict
# Out:
# {1: 20,
#  2: 223,
#  3: 755,
#  4: 1723,
#  5: 3390,
#  6: 4617,
#  7: 6049,
#  8: 7105,
#  9: 6989,
#  10: 6146,
#  11: 4738,
#  12: 3441,
#  13: 2491,
#  14: 1666,
#  15: 1030,
#  16: 674,
#  17: 381,
#  18: 275,
#  19: 138,
#  20: 78,
#  21: 62,
#  22: 37,
#  23: 30,
#  24: 23,
#  25: 22,
#  26: 10,
#  27: 9,
#  28: 4,
#  29: 4,
#  30: 4,
#  31: 2,
#  32: 1,
#  34: 1}

# %% [markdown]
# Распределение слов по количеству букв похоже на нормальное со смещением вправо: в частотном словаре больше всего слов из восьми букв, наименьшее количество букв - одна (двадцать слов), наибольшее - 34 (одно слово).
# Напишем функцию, которая выбирает из частотного словаря слова указанной длины:

# %%
def wLenCount(wLen,words = lst):
    sameLenList = []
    for word in words:
        lemma = word[0]
        if len(lemma) == wLen:
            sameLenList.append(word)
    return sameLenList

# %% [markdown]
# Теперь посчитаем однобуквенные слова и сразу посмотрим, какие это части речи:

# %%
oneletter = wLenCount(1)
for word in oneletter:
    print(word[0] + ', ' + ruPosNames[word[1]])
# Out:
# а, союз
# а, междометие
# а, частица
# а, существительное
# б, частица
# в, предлог
# ж, союз
# ж, частица
# и, союз
# к, предлог
# л, имя собственное
# м, междометие
# о, междометие
# о, предлог
# с, частица
# с, предлог
# у, междометие
# у, предлог
# э, междометие
# я, местоимение-существительное

# %% [markdown]
# С однобуквенными словами все более-менее ясно, в основном это служебные части речи: предлоги, частицы, союзы и так далее. Теперь посчитаем двухбуквенные слова и, поскольку их много, все выводить не будем, а посмотрим распределение по частям речи.

# %%
twoletters = wLenCount(2)
posTwoLetters = {}
for word in twoletters:
    if word[1] not in posTwoLetters:
        posTwoLetters[word[1]] = 0
    posTwoLetters[word[1]] += 1
for key,pos in posTwoLetters.items():
    print(ruPosNames[key] + ': ' + str(pos))
# Out:
# междометие: 38
# существительное: 46
# частица: 28
# местоимение-существительное: 10
# союз: 9
# имя собственное: 76
# предлог: 10
# местоимение-прилагательное: 2
# наречие: 2
# местоименное наречие: 2

# %% [markdown]
# Со служебными частями речи опять все понятно, они и должны быть короткими, и их много. А вот наречий - мало (всего 4, считая местоименные наречия), местоимений тоже не очень много (12). Глаголов и прилагательных вообще нет, и это логично: глаголы в инфинитиве в русском языке оканчиваются на "ть/ти" (иногда "чь"), и это уже две буквы, а для смысловой части (корня) букв уже не остаётся. Прилагательные мужского рода (именно это форма включена в частотный словарь) оканчиваются на "ой/ый/ий", и тут тоже две буквы заняты окончанием. Но вот интересно, что из 223 двухбуквенных слов целых 46 - существительные. Что это за слова? Я могу навскидку вспомнить "ад", "яд", "уж", "ёж", "ум" - ну и ещё парочку. Давайте посмотрим на все.

# %%
shortNouns = []
for word in twoletters:
    if word[1] == 's':
        shortNouns.append(word[0])
shortNouns
# Out:
# ['ад',
#  'аз',
#  'аи',
#  'ар',
#  'ас',
#  'бэ',
#  'вэ',
#  'го',
#  'гэ',
#  'до',
#  'дэ',
#  'еж',
#  'ер',
#  'ил',
#  'ля',
#  'но',
#  'ню',
#  'ом',
#  'ор',
#  'па',
#  'пи',
#  'пэ',
#  'ре',
#  'ро',
#  'рэ',
#  'си',
#  'тэ',
#  'уд',
#  'уж',
#  'ум',
#  'ус',
#  'фа',
#  'щи',
#  'эм',
#  'эн',
#  'эр',
#  'эс',
#  'юг',
#  'юз',
#  'юр',
#  'юс',
#  'ют',
#  'яд',
#  'як',
#  'ям',
#  'яр']

# %% [markdown]
# Признаться, без словаря смысл некоторых из этих слов останется для меня загадкой.
#
# Ещё одна загадка в том, что в списке есть все ноты, кроме "соль" и "ми". С "соль" все ясно, она не попала из-за длины. А вот куда делась "ми"? Я даже заглянула в файл с частотным словарем - нет там ноты "ми" и всё тут. Есть только слово "Ми", и это, очевидно, не нота, поскольку это имя собственное, и означает оно марку вертолётов. Нота "ми" потерялась, а составители частотного словаря и не подозревают. Вот и верь после этого авторитетным источникам.
#
# Ну и хватит с короткими словами, перейдем к длинным. Самое длинное слово, и оно одно, состоит из 34 букв. Что это за слово?

# %%
words34 = wLenCount(34)
words34[0][0]
# Out:
# 'информационно-телекоммуникационный'

# %% [markdown]
# Нуу... так нечестно. Это слово составное, с дефисом. А я хочу увидеть длинное-предлинное слово, которое не склеено из двух. Так что посмотрим следующее самое длинное слово, которое из 32 букв:

# %%
words32 = wLenCount(32)
words32[0][0]
# Out:
# 'экспериментально-психологический'

# %% [markdown]
# Опять то же самое... Интересно, на какой длине начинаются "нормальные" слова, без дефисов?

# %%
import re
for wLength in reversed(range(32)):    
    finish = False
    words = wLenCount(wLength)
    for word in words:
        hyphenFound = re.search('\-', word[0])
        if hyphenFound is None:
            print(word[0] + ', ' + str(wLength) + ' буквы')
            finish = True
            break
    if finish == True:
        break
# Out:
# высокопревосходительство, 24 буквы

# %% [markdown]
# Итак, в частотном словаре самое длинное слово без дефиса - это устаревшее слово из 24 букв "высокопревосходительство".

# %% [markdown]
# ## Можно ли выучить пятьдесят тысяч иностранных слов за минуту?
# Весьма авторитетный и уважаемый (мною в том числе) лингвист и преподаватель Дмитрий Петров говорит, что [можно](https://youtu.be/85wd0n9g2HY?t=144).
#
# По словам Петрова, во многих европейских языках существует около 50000 слов с одинаковым корнем и специфическим для языка окончанием, соответствующим русскому окончанию "-ция" или "-сия". В английском языке это окончания "-tion" и "-sion" соответственно. Получается, любой человек может "выучить" 50000 слов английского языка, зная правило перевода, то есть окончание, которое нужно подставить вместо "-ция/-сия".
# Давайте же посмотрим, сколько слов оканчивается на "-ция" или "-сия" в частотном словаре.

# %%
cialst = []
for one in lst:
    cia = re.search('[сц]ия$', one[0])
    if cia is not None and one[1] == 's':
        cialst.append(one[0])
len(cialst)
# Out:
# 635

# %% [markdown]
# 635 слов из 52138. Не так уж много, до пятидесяти тысяч очень далеко. И тут есть две новости, хорошая и плохая:
# - *Хорошая новость*. Русский язык значительно шире частотного ловаря, в нем насчитывается около 500 000 корней (см. [Википедию](https://ru.wikipedia.org/wiki/%D0%A1%D0%BB%D0%BE%D0%B2%D0%B0%D1%80%D0%BD%D1%8B%D0%B9_%D0%B7%D0%B0%D0%BF%D0%B0%D1%81)). Среди примерно 498 тысяч слов, которые не вошли в частотный словарь, теоретически может оказаться примерно 49300 слов, оканчивающихся на "-ция" или "-сия". Сомнительно, конечно, что 10% всех слов русского языка оканчиваются на "-ция/-сия", но, раз уж мы не можем это достоверно опровергнуть (нет у меня под рукой всех 500 тысяч слов), то остается согласиться, что это не исключено.
# - *Плохая новость*. Слова, попавшие в частотный словарь, более-менее часто используются в языке, а те, что "остались за бортом", используются редко либо практически никогда. Получается, что подавляющее большинство слов, оканчивающихся на "-ция/-сия", вы, вероятно, никогда в жизни не используете.
#
# Тут есть еще одна проблем. Если бы вы посмотрели на список слов с окончанием "-ция/-сия", то могли бы заметить, что некоторые из них переводятся иначе, чем указано в упомянутом "правиле перевода". Например, "эпилепсия" переводится на английский как "epilepsy" (не "epileption"), "грация" как "grace" (не "gration") и так далее. Давайте посчитаем, сколько таких исключений в нашем списке из 635 слов.
#
#
# Для этого я запишу список слов с окончаниями "-ция/-сия" в файл "cias.txt" и затем переводу его содержание через Google Translate (вручную). Результат я запишу в файл "tions.txt" (тоже вручную).

# %%
ciastr = ''
for one in cialst:
    ciastr = ciastr + str(one) + '\n'
file = open('cias.txt','w')
file.write(ciastr)
file.close()

# %% [markdown]
# Теперь нужно создать список переводов и посчитать слова, которые заканчиваются иначе, чем на "-tion/-sion".
# Следующая функция преобразует текст из указанного файла в список.

# %%
def readEndList(file):
    with open(file, 'r', encoding='utf-8') as f:
        text = f.read()
        strings =  text.split('\n')
        endList  = list(strings)
    return endList

# %% [markdown]
# Следующая функция:
# - берет объект "список", созданный на предыдущем этапе
# - находит слова, которые оканчиваются иначе, чем в указанном правиле
# - возвращает найденные слова в виде словаря, где ключом является слово на русском, а значением - перевод этого слова.

# %%
def ruleMatching(endRule,endList,sourceList = cialst):
    notByRule = {}
    for ind,val in enumerate(endList):	
        if re.search(endRule, val) is None:
            notByRule[cialst[ind]] = val
    return notByRule

# %% [markdown]
# Теперь применим эти функции, чтобы посмотреть, сколько слов с окончанием "-ция/-сия" в переводе на английски имеют окончания, отличные от "-tion" или "-sion".

# %%
tions = readEndList('tions.txt')
notByRuleEng = ruleMatching('[ts]ion$', tions)
print(len(notByRuleEng))
notByRuleEng
# Out:
# 118
# {'акация': 'acacia',
#  'акция': 'stock',
#  'апелляция': 'appeal',
#  'аппликация': 'applique',
#  'ассигнация': 'banknote',
#  'аудиенция': 'audience',
#  'вакансия': 'job vacancy',
#  'герметизация': 'sealing',
#  'гидроизоляция': 'waterproofing',
#  'гипоксия': 'hypoxia',
#  'гравитация': 'gravity',
#  'грация': 'grace',
#  'дегазация': 'degassing',
#  'дегустация': 'tasting',
#  'деменция': 'dementia',
#  'детализация': 'detailing',
#  'дивергенция': 'divergence',
#  'диверсия': 'sabotage',
#  'дирекция': 'directorate',
#  'дискредитация': 'discredit',
#  'диспетчеризация': 'dispatching',
#  'диссертация': 'thesis',
#  'дистанция': 'distance',
#  'дотация': 'subsidy',
#  'еврооблигация': 'eurobonds',
#  'звукоизоляция': 'soundproofing',
#  'иллюминация': 'illuminations',
#  'импотенция': 'impotence',
#  'инвентаризация': 'inventory',
#  'инвестиция': 'investment',
#  'индексация': 'indexing',
#  'индульгенция': 'indulgence',
#  'инерция': 'inertia',
#  'инкрустация': 'inlay',
#  'инстанция': 'instance',
#  'инструкция': 'manual',
#  'интеллигенция': 'intelligentsia',
#  'интенция': 'intent',
#  'интерференция': 'interference',
#  'интронизация': 'enthronement',
#  'канализация': 'sewerage',
#  'капитуляция': 'surrender',
#  'каталогизация': 'cataloging',
#  'квинтэссенция': 'quintessence',
#  'квитанция': 'receipt',
#  'коммерция': 'commerce',
#  'компетенция': 'competence',
#  'комплектация': 'equipment',
#  'комплекция': 'complexion',
#  'компрометация': 'compromising',
#  'конвергенция': 'convergence',
#  'консистенция': 'consistency',
#  'конспирация': 'conspiracy',
#  'констатация': 'ascertaining',
#  'конструкция': 'design',
#  'конференция': 'conference',
#  'концепция': 'concept',
#  'корреспонденция': 'correspondence',
#  'лекция': 'lecture',
#  'лоция': 'sailing ship',
#  'люминесценция': 'luminescence',
#  'махинация': 'machinations',
#  'медкомиссия': 'medical board',
#  'мессия': 'Messiah',
#  'металлоконструкция': 'metalwork',
#  'металлопродукция': 'metal products',
#  'милиция': 'militia',
#  'мистификация': 'hoax',
#  'настурция': 'nasturtium',
#  'нумерация': 'numbering',
#  'облигация': 'bond',
#  'ортодоксия': 'orthodoxy',
#  'партконференция': 'party conference',
#  'передислокация': 'redeployment',
#  'переквалификация': 'retraining',
#  'персистенция': 'persistence',
#  'полиция': 'police',
#  'потенция': 'potency',
#  'пресс-конференция': 'press conference',
#  'преференция': 'preference',
#  'провинция': 'provinces',
#  'протекция': 'patronage',
#  'пульсация': 'ripple',
#  'радиолокация': 'radar',
#  'рация': 'portable radio',
#  'реализация': 'realization of',
#  'реассортация': 'reassortment',
#  'регистрация': 'check in',
#  'резиденция': 'residence',
#  'реминисценция': 'reminiscence',
#  'репарация': 'repair',
#  'ресторация': 'restaurant',
#  'реструктуризация': 'restructuring',
#  'рыбопродукция': 'fish products',
#  'сельхозпродукция': 'agricultural products',
#  'сентенция': 'maxim',
#  'сигнализация': 'signaling',
#  'специя': 'spice',
#  'старушенция': 'aging',
#  'структуризация': 'structuring',
#  'субстанция': 'substance',
#  'тарификация': 'charging',
#  'телекоммуникация': 'telecommunications',
#  'тенденция': 'trend',
#  'терция': 'third',
#  'трансляция': 'broadcast',
#  'трапеция': 'trapeze',
#  'унция': 'ounce',
#  'утилизация': 'recycling',
#  'фасция': 'fascia',
#  'флексия': 'flexion',
#  'фотолюминесценция': 'photoluminescence',
#  'экзистенция': 'existence',
#  'электролюминесценция': 'electroluminescence',
#  'эпилепсия': 'epilepsy',
#  'эссенция': 'essence',
#  'юриспруденция': 'jurisprudence',
#  'юстиция': 'justice'}

# %% [markdown]
# 118 исключений из 635 слов! По-моему, многовато.
#
# Теперь посмотрим, скажем, на португальский. Из все тех же уроков Дмитрия Петрова мы узнаем, что окончаниям "-ция/-сия" в португальском соответствет окончание "-ção". После перевода на португальский (его вы найдете в файле caos.txt) снова используем наши функции, чтобы проверить список на наличие исключений.

# %%
caos = readEndList('caos.txt')
notByRulePort = ruleMatching('ção$', caos)
print(len(notByRulePort))
notByRulePort
# Out:
# 191
# {'авиация': 'aeronave',
#  'автоинспекция': 'inspeção automática',
#  'автостанция': 'estação de ônibus',
#  'агрессия': 'agressão',
#  'акация': 'acácia',
#  'акция': 'stock',
#  'аннотация': 'resumo',
#  'апелляция': 'apelo',
#  'ассигнация': 'nota de banco',
#  'аттестация': 'atestado',
#  'аудиенция': 'audiência',
#  'вакансия': 'vaga',
#  'версия': 'versão',
#  'видеопродукция': 'produção de video',
#  'вич-инфекция': 'Infecção por HIV',
#  'геоинформация': 'geoinformation',
#  'гидроэлектростанция': 'estação de energia hidrelétrica',
#  'гипоксия': 'hipoxia',
#  'горадминистрация': 'administração da cidade',
#  'госкомиссия': 'comissão estadual',
#  'гравитация': 'gravidade',
#  'грация': 'graça',
#  'девиация': 'desvio',
#  'декорация': 'cenário',
#  'деменция': 'demência',
#  'депопуляция': 'despovoamento',
#  'депрессия': 'depressão',
#  'детализация': 'detalhando',
#  'дивергенция': 'divergência',
#  'диверсия': 'sabotagem',
#  'дирекция': 'diretor',
#  'дискредитация': 'desacreditar',
#  'дискуссия': 'debate',
#  'дислокация': 'deslocamento',
#  'диспансеризация': 'exame médico profilático',
#  'дисперсия': 'variância',
#  'диспетчеризация': 'despachando',
#  'диссертация': 'tese',
#  'дистанция': 'distância',
#  'допэмиссия': 'emissão adicional',
#  'дотация': 'subsídio',
#  'еврооблигация': 'Eurobonds',
#  'изоляция': 'isolamento',
#  'импотенция': 'impotência',
#  'инвентаризация': 'inventário',
#  'инверсия': 'inversão',
#  'инвестиция': 'investimento',
#  'индикация': 'indicações',
#  'индульгенция': 'indulgência',
#  'инерция': 'inércia',
#  'инстанция': 'instância',
#  'инструкция': 'manual',
#  'интеллигенция': 'intelligentsia',
#  'интерференция': 'interferência',
#  'калькуляция': 'cálculo',
#  'канализация': 'esgoto',
#  'катавасия': 'catavasia',
#  'квинтэссенция': 'quintessência',
#  'квитанция': 'recibos',
#  'комиссия': 'comissão',
#  'коммерция': 'comércio',
#  'компетенция': 'competência',
#  'комплектация': 'escolhendo',
#  'комплекция': 'complexion',
#  'компрометация': 'comprometendo',
#  'конвергенция': 'convergência',
#  'конверсия': 'Conversão',
#  'конвертация': 'conversão',
#  'конвульсия': 'convulsão',
#  'консистенция': 'consistência',
#  'констатация': 'verificar',
#  'конструкция': 'estrutura',
#  'консультация': 'conselho',
#  'конференция': 'conferência',
#  'конфессия': 'confissão',
#  'конфискация': 'confisco',
#  'конфронтация': 'confronto',
#  'концессия': 'concessão',
#  'коррекция': 'ajuste',
#  'корреспонденция': 'correspondência',
#  'лекция': 'palestra',
#  'лоция': 'veleiro',
#  'люминесценция': 'luminescência',
#  'махинация': 'maquinações',
#  'медкомиссия': 'quadro médico',
#  'мелиорация': 'melhoramento',
#  'мессия': 'messias',
#  'металлоконструкция': 'trabalho em metal',
#  'металлопродукция': 'produtos metálicos',
#  'метеостанция': 'estação meteorológica',
#  'милиция': 'milícia',
#  'миссия': 'missão',
#  'мистификация': 'embuste',
#  'мультипликация': 'desenho animado',
#  'настурция': 'capuchinha',
#  'обладминистрация': 'administração regional',
#  'облигация': 'vínculo',
#  'ортодоксия': 'ortodoxia',
#  'партконференция': 'conferência do partido',
#  'парторганизация': 'organização do partido',
#  'пассия': 'paixão',
#  'пенсия': 'pensão',
#  'перверсия': 'perversão',
#  'переквалификация': 'reciclagem',
#  'персистенция': 'persistência',
#  'подкомиссия': 'subcomissão',
#  'политизация': 'politizando',
#  'политинформация': 'informação política',
#  'полиция': 'a polícia',
#  'поллюция': 'emissão',
#  'порция': 'lote',
#  'потенция': 'potência',
#  'потребкооперация': 'cooperação do consumidor',
#  'пресс-конференция': 'conferência de imprensa',
#  'преференция': 'preferência',
#  'провинция': 'província',
#  'прогрессия': 'progressão',
#  'пролонгация': 'prolongamento',
#  'протекция': 'patrocínio',
#  'профессия': 'profissão',
#  'процессия': 'procissão',
#  'радиолокация': 'radar',
#  'радиостанция': 'estação de rádio',
#  'рационализация': 'agilizando',
#  'рация': 'rádio portátil',
#  'реализация': 'realização de',
#  'реассортация': 'reassortment',
#  'реверсия': 'reversão',
#  'регистрация': 'registro',
#  'регламентация': 'regulamento',
#  'регрессия': 'regressão',
#  'регуляция': 'Regulamento',
#  'резервация': 'reserva',
#  'резиденция': 'residência',
#  'релаксация': 'relaxamento',
#  'реминисценция': 'reminiscência',
#  'ремиссия': 'remissão',
#  'репетиция': 'ensaio',
#  'репрессия': 'repressão',
#  'ресторация': 'restaurante',
#  'рефлексия': 'reflexão',
#  'реформация': 'reforma',
#  'рецессия': 'recessão',
#  'рыбопродукция': 'produtos de peixe',
#  'самоизоляция': 'auto-isolamento',
#  'санация': 'saneamento',
#  'санэпидстанция': 'estação sanitária',
#  'сельхозпродукция': 'produtos agrícolas',
#  'сентенция': 'máxima',
#  'сероконверсия': 'seroconversão',
#  'сессия': 'sessão',
#  'сигнализация': 'sistema de alarme',
#  'специя': 'temperar',
#  'спецоперация': 'operação especial',
#  'старушенция': 'envelhecimento',
#  'субстанция': 'substância',
#  'тарификация': 'cobrando',
#  'телекоммуникация': 'telecomunicações',
#  'тенденция': 'tendência',
#  'теплоизоляция': 'isolamento térmico',
#  'терция': 'terços',
#  'трансгрессия': 'transgressão',
#  'трансляция': 'transmissão',
#  'трансмиссия': 'transmissão',
#  'трансплантация': 'transplante',
#  'трапеция': 'trapézio',
#  'трепанация': 'trepidez',
#  'унция': 'onça',
#  'утилизация': 'reciclagem',
#  'фасция': 'fascia',
#  'флексия': 'inflexão',
#  'фотолюминесценция': 'fotoluminescência',
#  'фотосессия': 'sessão de fotos',
#  'функция': 'recurso',
#  'химизация': 'química',
#  'цессия': 'cessão',
#  'экзистенция': 'existência',
#  'экранизация': 'adaptação de tela',
#  'экскурсия': 'excursão',
#  'экспансия': 'expansão',
#  'экспрессия': 'expressão',
#  'электролюминесценция': 'eletroluminescência',
#  'электростанция': 'estação de energia',
#  'эмиссия': 'emissão',
#  'эмульсия': 'emulsão',
#  'эпилепсия': 'epilepsia',
#  'эрекция': 'gordinho',
#  'эскалация': 'escalada',
#  'эссенция': 'essência',
#  'юриспруденция': 'jurisprudência',
#  'юстиция': 'judiciário'}

# %% [markdown]
# И тут аж 191 исключение! Хотя стоп, если вы посмотрите на список португальских слов, то можете заметить еще два окончания, которые повторяются многократно: "-ssão" и "-cia". Похоже, нужно добавить их в правило.

# %%
notByRulePort2 = ruleMatching('([çs{2}]ão$)|(cia$)', caos)
print(len(notByRulePort2))
notByRulePort2
# Out:
# 123
# {'авиация': 'aeronave',
#  'автоинспекция': 'inspeção automática',
#  'автостанция': 'estação de ônibus',
#  'акция': 'stock',
#  'аннотация': 'resumo',
#  'апелляция': 'apelo',
#  'ассигнация': 'nota de banco',
#  'аттестация': 'atestado',
#  'вакансия': 'vaga',
#  'видеопродукция': 'produção de video',
#  'вич-инфекция': 'Infecção por HIV',
#  'геоинформация': 'geoinformation',
#  'гидроэлектростанция': 'estação de energia hidrelétrica',
#  'гипоксия': 'hipoxia',
#  'горадминистрация': 'administração da cidade',
#  'госкомиссия': 'comissão estadual',
#  'гравитация': 'gravidade',
#  'грация': 'graça',
#  'девиация': 'desvio',
#  'декорация': 'cenário',
#  'депопуляция': 'despovoamento',
#  'детализация': 'detalhando',
#  'диверсия': 'sabotagem',
#  'дирекция': 'diretor',
#  'дискредитация': 'desacreditar',
#  'дискуссия': 'debate',
#  'дислокация': 'deslocamento',
#  'диспансеризация': 'exame médico profilático',
#  'диспетчеризация': 'despachando',
#  'диссертация': 'tese',
#  'допэмиссия': 'emissão adicional',
#  'дотация': 'subsídio',
#  'еврооблигация': 'Eurobonds',
#  'изоляция': 'isolamento',
#  'инвентаризация': 'inventário',
#  'инвестиция': 'investimento',
#  'индикация': 'indicações',
#  'инструкция': 'manual',
#  'интеллигенция': 'intelligentsia',
#  'калькуляция': 'cálculo',
#  'канализация': 'esgoto',
#  'катавасия': 'catavasia',
#  'квитанция': 'recibos',
#  'коммерция': 'comércio',
#  'комплектация': 'escolhendo',
#  'комплекция': 'complexion',
#  'компрометация': 'comprometendo',
#  'констатация': 'verificar',
#  'конструкция': 'estrutura',
#  'консультация': 'conselho',
#  'конфискация': 'confisco',
#  'конфронтация': 'confronto',
#  'коррекция': 'ajuste',
#  'лекция': 'palestra',
#  'лоция': 'veleiro',
#  'махинация': 'maquinações',
#  'медкомиссия': 'quadro médico',
#  'мелиорация': 'melhoramento',
#  'мессия': 'messias',
#  'металлоконструкция': 'trabalho em metal',
#  'металлопродукция': 'produtos metálicos',
#  'метеостанция': 'estação meteorológica',
#  'мистификация': 'embuste',
#  'мультипликация': 'desenho animado',
#  'настурция': 'capuchinha',
#  'обладминистрация': 'administração regional',
#  'облигация': 'vínculo',
#  'ортодоксия': 'ortodoxia',
#  'партконференция': 'conferência do partido',
#  'парторганизация': 'organização do partido',
#  'пассия': 'paixão',
#  'переквалификация': 'reciclagem',
#  'политизация': 'politizando',
#  'политинформация': 'informação política',
#  'порция': 'lote',
#  'потребкооперация': 'cooperação do consumidor',
#  'пресс-конференция': 'conferência de imprensa',
#  'пролонгация': 'prolongamento',
#  'протекция': 'patrocínio',
#  'радиолокация': 'radar',
#  'радиостанция': 'estação de rádio',
#  'рационализация': 'agilizando',
#  'рация': 'rádio portátil',
#  'реализация': 'realização de',
#  'реассортация': 'reassortment',
#  'регистрация': 'registro',
#  'регламентация': 'regulamento',
#  'регуляция': 'Regulamento',
#  'резервация': 'reserva',
#  'релаксация': 'relaxamento',
#  'репетиция': 'ensaio',
#  'ресторация': 'restaurante',
#  'рефлексия': 'reflexão',
#  'реформация': 'reforma',
#  'рыбопродукция': 'produtos de peixe',
#  'самоизоляция': 'auto-isolamento',
#  'санация': 'saneamento',
#  'санэпидстанция': 'estação sanitária',
#  'сельхозпродукция': 'produtos agrícolas',
#  'сентенция': 'máxima',
#  'сигнализация': 'sistema de alarme',
#  'специя': 'temperar',
#  'спецоперация': 'operação especial',
#  'старушенция': 'envelhecimento',
#  'тарификация': 'cobrando',
#  'телекоммуникация': 'telecomunicações',
#  'теплоизоляция': 'isolamento térmico',
#  'терция': 'terços',
#  'трансплантация': 'transplante',
#  'трапеция': 'trapézio',
#  'трепанация': 'trepidez',
#  'унция': 'onça',
#  'утилизация': 'reciclagem',
#  'флексия': 'inflexão',
#  'фотосессия': 'sessão de fotos',
#  'функция': 'recurso',
#  'химизация': 'química',
#  'экранизация': 'adaptação de tela',
#  'электростанция': 'estação de energia',
#  'эпилепсия': 'epilepsia',
#  'эрекция': 'gordinho',
#  'эскалация': 'escalada',
#  'юстиция': 'judiciário'}

# %% [markdown]
# Получилось 123 исключения вместо 191. С одной стороны, чем меньше исключений, тем лучше. С другой, правило перевода усложнилось: теперь при переводе на португальский нужно выбрать между "-ção/-ssão" (которые звучат одинаково) и "-cia".
#
# Теперь давайте объединим два списка исключений, английски и португальский, и найдем те слова, которые на оба языка переводятся не по правилу.

# %%
notByRuleEngPort = {}
for key,value in notByRulePort2.items():
    if key in notByRuleEng:
        notByRuleEngPort[key] = []
        notByRuleEngPort[key].append(notByRuleEng[key])
        notByRuleEngPort[key].append(value)		
print(len(notByRuleEngPort))
notByRuleEngPort
# Out:
# 63
# {'акция': ['stock', 'stock'],
#  'апелляция': ['appeal', 'apelo'],
#  'ассигнация': ['banknote', 'nota de banco'],
#  'вакансия': ['job vacancy', 'vaga'],
#  'гипоксия': ['hypoxia', 'hipoxia'],
#  'гравитация': ['gravity', 'gravidade'],
#  'грация': ['grace', 'graça'],
#  'детализация': ['detailing', 'detalhando'],
#  'диверсия': ['sabotage', 'sabotagem'],
#  'дирекция': ['directorate', 'diretor'],
#  'дискредитация': ['discredit', 'desacreditar'],
#  'диспетчеризация': ['dispatching', 'despachando'],
#  'диссертация': ['thesis', 'tese'],
#  'дотация': ['subsidy', 'subsídio'],
#  'еврооблигация': ['eurobonds', 'Eurobonds'],
#  'инвентаризация': ['inventory', 'inventário'],
#  'инвестиция': ['investment', 'investimento'],
#  'инструкция': ['manual', 'manual'],
#  'интеллигенция': ['intelligentsia', 'intelligentsia'],
#  'канализация': ['sewerage', 'esgoto'],
#  'квитанция': ['receipt', 'recibos'],
#  'коммерция': ['commerce', 'comércio'],
#  'комплектация': ['equipment', 'escolhendo'],
#  'комплекция': ['complexion', 'complexion'],
#  'компрометация': ['compromising', 'comprometendo'],
#  'констатация': ['ascertaining', 'verificar'],
#  'конструкция': ['design', 'estrutura'],
#  'лекция': ['lecture', 'palestra'],
#  'лоция': ['sailing ship', 'veleiro'],
#  'махинация': ['machinations', 'maquinações'],
#  'медкомиссия': ['medical board', 'quadro médico'],
#  'мессия': ['Messiah', 'messias'],
#  'металлоконструкция': ['metalwork', 'trabalho em metal'],
#  'металлопродукция': ['metal products', 'produtos metálicos'],
#  'мистификация': ['hoax', 'embuste'],
#  'настурция': ['nasturtium', 'capuchinha'],
#  'облигация': ['bond', 'vínculo'],
#  'ортодоксия': ['orthodoxy', 'ortodoxia'],
#  'партконференция': ['party conference', 'conferência do partido'],
#  'переквалификация': ['retraining', 'reciclagem'],
#  'пресс-конференция': ['press conference', 'conferência de imprensa'],
#  'протекция': ['patronage', 'patrocínio'],
#  'радиолокация': ['radar', 'radar'],
#  'рация': ['portable radio', 'rádio portátil'],
#  'реализация': ['realization of', 'realização de'],
#  'реассортация': ['reassortment', 'reassortment'],
#  'регистрация': ['check in', 'registro'],
#  'ресторация': ['restaurant', 'restaurante'],
#  'рыбопродукция': ['fish products', 'produtos de peixe'],
#  'сельхозпродукция': ['agricultural products', 'produtos agrícolas'],
#  'сентенция': ['maxim', 'máxima'],
#  'сигнализация': ['signaling', 'sistema de alarme'],
#  'специя': ['spice', 'temperar'],
#  'старушенция': ['aging', 'envelhecimento'],
#  'тарификация': ['charging', 'cobrando'],
#  'телекоммуникация': ['telecommunications', 'telecomunicações'],
#  'терция': ['third', 'terços'],
#  'трапеция': ['trapeze', 'trapézio'],
#  'унция': ['ounce', 'onça'],
#  'утилизация': ['recycling', 'reciclagem'],
#  'флексия': ['flexion', 'inflexão'],
#  'эпилепсия': ['epilepsy', 'epilepsia'],
#  'юстиция': ['justice', 'judiciário']}

# %% [markdown]
# 63 слова. 10% от списка русских слов с окончанием "-ция/-сия" приведут к ошибке, если попытаться перевести их на английский или португальский по правилу. Конечно, если у вас развито чувство языка, вы можете интуитивно опеределить некоторые из этих слов, такие как "настурция" ("nasturtium") или "специя" ("spice"). Что касается меня, я не уверена, что определила бы даже половину.
#
# ### Вывод
# Можно ли выучить пятьдесят тысяч иностранных слов за минуту? Может быть, и можно, но:
# - подавляющее большинство из этих слов вы, вероятно, ни разу в жизни не используете;
# - вероятность ошибиться, переводя слова с окончанием на "-ция/-сия" по правилу, довольно велика.
#
# P.s. Вообще-то я думаю, что Дмитрий Петров просто оговорился, потому что в других передачах он уже не говорит о пятидесяти тысячах слов, а говорит просто про "тысячи".

# %% [markdown]
# ## Легкопроизносимые и труднопроизносимые слова
#
# Попробуйте произнести фразу "У вальдшнепа всклокоченная шёрстка". Если русский - ваш родной язык, то с этой задачей вы справитесь, глазом не моргнув (даже несмотря на то, что у вальдшнепа шёрстки, в общем-то, нет). А между тем в каждом из слов этой фразы (кроме предлога "у") есть сочетание нескольких согласных букв подряд. Для иностранцев, изучающих русский, такие слова могут оказаться настоящим препятствием.
#
# В этой части исследования мы посмотрим, сколько же в нашем частотном словаре слов с труднопроизносимыми сочетаниями согласных (четыре или больше согласных подряд).
#
# Здесь следует принять во внимание, что в русском языке есть не только гласные и согласные буквы, но буквы, которые не относятся ни к гласным, ни к согласным: "ъ", "ь" и "й". Поэтому некоторые сочетания букв следует считать сочетаниями согласных с учётом этого факта. Так, например, в конце слова "вскользь" после гласной буквы "о" идут четыре буквы, две из которых ("л" и "з") - согласные, а две другие (мягкие знаки) служат только для смягчения согласных. Поэтому, с точки зрения произношения, эти четыре буквы вернее было бы считать сочетанием двух согласных.
#
# Чтобы упростить задачу и не писать сложных регулярных выражений, которые учитывали бы эту особенность русского языка, мы проведём предварительную обработку частотного словаря и создадим для каждого слова *звуковую модель*, в которой гласные будут обозначены латинской буквой *a*, согласные - буквой *b*, а буквы "ъ", "ь" и "й" будут вовсе удалены. Удалим мы также небуквенные символы: дефисы и апострофы. Результат запишем в словарь modelDict, где ключом будет русское слово, а значением - звуковая модель этого слова.

# %%
modelDict = {}
for one in lst:
    modelCons = re.sub('[БбВвГгДдЖжЗзКкЛлМмНнПпРрСсТтФфХхЦцЧчШшЩщ]','b',one[0])
    modelVow = re.sub('[АаЯяОоЁёЭэЕеУуЮюИиЫы]','a',modelCons)
    model = re.sub('[Ййьъ\-\']','',modelVow)
    modelDict[one[0]] = model
print(len(modelDict))
print(modelDict['ай-ай-ай'])
print(modelDict['съесть'])
# Out:
# 51733
# aaa
# babb

# %% [markdown]
# Отлично, словарь готов. Проверим, все ли верно обработано, не осталось ли символов, которые не являются ни a, ни b.

# %%
notAB = []
for key,model in modelDict.items():
    if re.search('[^ab]', model) is not None:
        notAB.append(model)
print(notAB)
# Out:
# []

# %% [markdown]
# Напишем функцию, которая берет словарь и проверяет модель на соответствие регулярному выражению (pattern)

# %%
def countMatches(pattern):
    lst = []
    for key,model in modelDict.items():
        if re.search(pattern, model) is not None:
            lst.append(key)
    return lst

# %% [markdown]
# И теперь используем эту функцию, чтобы подсчитать количество труднопроизносимых слов, то есть слов, где есть четыре или больше согласных подряд.

# %%
hardWords = countMatches('bbbb')
print(len(hardWords))
hardWords[:10]
# Out:
# 1125
# ['аббатство',
#  'абонентский',
#  'абстрагирование',
#  'абстрагировать',
#  'абстрагироваться',
#  'абстрактно',
#  'абстрактный',
#  'абстракционизм',
#  'абстракционист',
#  'абстракция']

# %% [markdown]
# 1125 труднопроизносимых слов в частотном словаре. Много это или мало? Не знаю. Давайте сравним с количеством легкопроизносимых слов, а такими будем считать слова, где гласная чередуется с согласной. Ну и слишком короткие слова считать не будем, возьмем слова минимум из трех слогов.

# %%
easyWords = countMatches('^b?(ab){2,}ab?$')
print(len(easyWords))
print(easyWords[:10])
# Out:
# 5297
# ['абажур', 'абориген', 'аварийный', 'авеню', 'авитаминоз', 'авокадо', 'Агата', 'агитатор', 'агитировать', 'агонизировать']

# %% [markdown]
# Легкопроизносимых слов в словаре 5297. А что насчет слов, где несколько подряд гласных? Сколько в частотном словаре таких вот певучих слов?

# %%
melodWords = countMatches('aaa')
print(len(melodWords))
print(melodWords)
# Out:
# 50
# ['ааа', 'а-а-а', 'а-а-а-а', 'авиаотряд', 'ай-ай-ай', 'ай-яй-яй', 'брандмауэр', 'геоинформатика', 'геоинформационный', 'геоинформация', 'геоэкологический', 'да-а-а', 'Иоанн', 'краеугольный', 'метеоусловия', 'не-е-ет', 'неуемный', 'неуют', 'неуютно', 'неуютный', 'неуязвимость', 'неуязвимый', 'ОАО', 'ОИЯИ', 'ой-ой-ой', 'ООО', 'о-о-о', 'протоиерей', 'радиоактивность', 'радиоактивный', 'радиоаппаратура', 'радиоастроном', 'радиоастрономия', 'радиоизлучение', 'радиоисточник', 'радиоузел', 'радиоуправляемый', 'радиоэлектроника', 'радиоэлектронный', 'радиоэфир', 'своеобразие', 'своеобразно', 'своеобразный', 'своеобычный', 'ууу', 'у-у-у', 'что-о-о', 'Эйзенхауэр', 'эээ', 'э-э-э']

# %% [markdown]
# Всего-то 50. Не очень певуч наш язык. Заметили, как замечательно получаются певучие слова, составленные из слова "радио" и другого слова с первой гласной?

# %% [markdown]
# ## Считаем омонимы
# Вы могли заметить, что количество элементов в словаре modelDict (словарь "звуковых моделей") меньше, чем количество элементов в частотном словаре. Взглянем на это еще раз:

# %%
print('Элементов в частотном словаре: ' + str(wordsTotal))
print('Элементов в словаре "звуковых моделей": ' + str(len(modelDict)))
# Out:
# Элементов в частотном словаре: 52138
# Элементов в словаре "звуковых моделей": 51733

# %% [markdown]
# Разница связана с наличием в частотном словаре *омонимов*, то есть слов, которые пишутся одинаково, но имеют разное значение. Омонимы, которые относятся к одной части речи (например, существительное "лук" может обозначать растение или оружие) по частотному словарю вычислить не получится, так как такие омонимы в нем не разделены. А вот омонимы, которые относятся к разным частям речи (например, существительное "печь" - то есть печка, и глагол "печь" - то есть выпекать) посчитать можно.
#
# Для начала составим словарь omd, в котором ключом является слово, а значением - список соответствующих ему частей речи. В основном список частей речи будет содержать только один элемент, так как большинству слов соответствует только одна часть речи.

# %%
omd = {}
for word in lst:
    lemma = word[0]
    pos = word[1]
    if lemma not in omd:
        omd[lemma] = []
    omd[lemma].append(ruPosNames[pos])    
omd['слово']
# Out:
# ['существительное']

# %% [markdown]
# Теперь из полученного словаря omd извлечем омонимы, то есть слова, которым соответствует больше одной части речи. Извлеченные омонимы добавим в словарь omfin.

# %%
omfin = {}
for word in omd:
    if len(omd[word]) > 1:
        omfin[word] = omd[word]
print(len(omfin))
omfin
# Out:
# 378
# {'Постников': ['имя собственное', 'имя собственное'],
#  'а': ['союз', 'междометие', 'частица', 'существительное'],
#  'ага': ['междометие', 'частица', 'существительное'],
#  'аз': ['существительное', 'местоимение-существительное'],
#  'аккурат': ['наречие', 'существительное'],
#  'але': ['междометие', 'частица'],
#  'аль': ['союз', 'частица'],
#  'альфа': ['прилагательное', 'существительное'],
#  'аминь': ['наречие', 'частица'],
#  'барокко': ['прилагательное', 'существительное'],
#  'бац': ['наречие', 'междометие'],
#  'беда': ['наречие', 'существительное'],
#  'бездомный': ['прилагательное', 'существительное'],
#  'безработный': ['прилагательное', 'существительное'],
#  'белый': ['прилагательное', 'существительное'],
#  'бис': ['междометие', 'существительное'],
#  'благо': ['союз', 'существительное'],
#  'благоверный': ['прилагательное', 'существительное'],
#  'блатной': ['прилагательное', 'существительное'],
#  'ближний': ['прилагательное', 'существительное'],
#  'блин': ['междометие', 'существительное'],
#  'бля': ['междометие', 'частица'],
#  'блядь': ['междометие', 'существительное'],
#  'более': ['наречие', 'количественное числительное'],
#  'больной': ['прилагательное', 'существительное'],
#  'больше': ['наречие', 'количественное числительное'],
#  'браво': ['наречие', 'междометие'],
#  'бритоголовый': ['прилагательное', 'существительное'],
#  'будто': ['союз', 'частица'],
#  'буль-буль': ['наречие', 'междометие'],
#  'бум': ['междометие', 'существительное'],
#  'вахтенный': ['прилагательное', 'существительное'],
#  'вблизи': ['наречие', 'предлог'],
#  'вглубь': ['наречие', 'предлог'],
#  'вдоль': ['наречие', 'предлог'],
#  'ведомо': ['наречие', 'существительное'],
#  'ведомый': ['прилагательное', 'существительное'],
#  'ведущий': ['прилагательное', 'существительное'],
#  'ведь': ['союз', 'частица'],
#  'век': ['наречие', 'существительное'],
#  'верующий': ['прилагательное', 'существительное'],
#  'верховой': ['прилагательное', 'существительное'],
#  'весть': ['существительное', 'глагол'],
#  'весь': ['местоимение-прилагательное', 'существительное'],
#  'взамен': ['наречие', 'предлог'],
#  'взрослый': ['прилагательное', 'существительное'],
#  'видать': ['наречие', 'глагол'],
#  'визави': ['наречие', 'существительное'],
#  'виновный': ['прилагательное', 'существительное'],
#  'влюбленный': ['прилагательное', 'существительное'],
#  'внизу': ['наречие', 'предлог'],
#  'внутри': ['наречие', 'предлог'],
#  'внутрь': ['наречие', 'предлог'],
#  'во': ['частица', 'предлог'],
#  'во-во': ['междометие', 'частица'],
#  'водяной': ['прилагательное', 'существительное'],
#  'военный': ['прилагательное', 'существительное'],
#  'возле': ['наречие', 'предлог'],
#  'возлюбленный': ['прилагательное', 'существительное'],
#  'вокруг': ['наречие', 'предлог'],
#  'вольный': ['прилагательное', 'существительное'],
#  'вон': ['местоименное наречие', 'частица'],
#  'вона': ['местоименное наречие', 'частица'],
#  'вообще-то': ['наречие', 'частица'],
#  'вослед': ['наречие', 'предлог'],
#  'вперед': ['наречие', 'предлог'],
#  'впереди': ['наречие', 'предлог'],
#  'впрямь': ['наречие', 'частица'],
#  'вроде': ['наречие', 'частица', 'предлог'],
#  'все': ['местоименное наречие', 'частица', 'местоимение-существительное'],
#  'все-таки': ['союз', 'частица'],
#  'всего': ['местоименное наречие', 'частица'],
#  'вслед': ['наречие', 'предлог'],
#  'выпускной': ['прилагательное', 'существительное'],
#  'выходной': ['прилагательное', 'существительное'],
#  'выше': ['наречие', 'предлог'],
#  'главное': ['наречие', 'существительное'],
#  'гласный': ['прилагательное', 'существительное'],
#  'глухой': ['прилагательное', 'существительное'],
#  'глухонемой': ['прилагательное', 'существительное'],
#  'говорящий': ['прилагательное', 'существительное'],
#  'голодающий': ['прилагательное', 'существительное'],
#  'грех': ['наречие', 'существительное'],
#  'да': ['союз', 'частица'],
#  'да-а': ['междометие', 'частица'],
#  'да-а-а': ['междометие', 'частица'],
#  'да-да-да': ['междометие', 'частица'],
#  'даже': ['союз', 'частица'],
#  'дак': ['союз', 'частица'],
#  'дежурный': ['прилагательное', 'существительное'],
#  'дер': ['частица', 'существительное'],
#  'до': ['предлог', 'существительное'],
#  'добро': ['наречие', 'частица', 'существительное'],
#  'доверенный': ['прилагательное', 'существительное'],
#  'дозорный': ['прилагательное', 'существительное'],
#  'доколе': ['местоименное наречие', 'союз'],
#  'дон': ['частица', 'существительное'],
#  'душевнобольной': ['прилагательное', 'существительное'],
#  'дык': ['наречие', 'частица'],
#  'едва': ['наречие', 'союз'],
#  'ездовой': ['прилагательное', 'существительное'],
#  'ето': ['частица', 'местоимение-существительное'],
#  'еще': ['наречие', 'частица'],
#  'ж': ['союз', 'частица'],
#  'же': ['союз', 'частица'],
#  'живой': ['прилагательное', 'существительное'],
#  'заключенный': ['прилагательное', 'существительное'],
#  'запасной': ['прилагательное', 'существительное'],
#  'здорово': ['наречие', 'междометие', 'частица'],
#  'здрасте': ['междометие', 'частица'],
#  'зло': ['наречие', 'существительное'],
#  'знакомый': ['прилагательное', 'существительное'],
#  'знать': ['наречие', 'существительное', 'глагол'],
#  'значит': ['наречие', 'частица'],
#  'золотой': ['прилагательное', 'существительное'],
#  'иже': ['местоимение-прилагательное', 'союз'],
#  'изнутри': ['наречие', 'предлог'],
#  'именно': ['наречие', 'частица'],
#  'имхо': ['наречие', 'частица'],
#  'инакомыслящий': ['прилагательное', 'существительное'],
#  'иначе': ['местоименное наречие', 'союз'],
#  'инкогнито': ['наречие', 'существительное'],
#  'иногородний': ['прилагательное', 'существительное'],
#  'исключительно': ['наречие', 'частица'],
#  'испытуемый': ['прилагательное', 'существительное'],
#  'ишь': ['междометие', 'частица'],
#  'как': ['местоименное наречие', 'союз', 'частица'],
#  'караул': ['междометие', 'существительное'],
#  'караульный': ['прилагательное', 'существительное'],
#  'когда': ['местоименное наречие', 'союз'],
#  'конвойный': ['прилагательное', 'существительное'],
#  'конечно': ['наречие', 'частица'],
#  'коренной': ['прилагательное', 'существительное'],
#  'коридорный': ['прилагательное', 'существительное'],
#  'косой': ['прилагательное', 'существительное'],
#  'крепостной': ['прилагательное', 'существительное'],
#  'крестный': ['прилагательное', 'существительное'],
#  'крещеный': ['прилагательное', 'существительное'],
#  'кривой': ['прилагательное', 'существительное'],
#  'кроме': ['наречие', 'предлог'],
#  'кругом': ['наречие', 'предлог'],
#  'ладно': ['наречие', 'частица'],
#  'левый': ['прилагательное', 'существительное'],
#  'лень': ['наречие', 'существительное'],
#  'ли': ['союз', 'частица'],
#  'лихо': ['наречие', 'существительное'],
#  'лишь': ['союз', 'частица'],
#  'лучше': ['наречие', 'частица'],
#  'ль': ['союз', 'частица'],
#  'любопытствующий': ['прилагательное', 'существительное'],
#  'люкс': ['прилагательное', 'существительное'],
#  'максимум': ['наречие', 'существительное'],
#  'мало': ['наречие', 'количественное числительное'],
#  'малость': ['наречие', 'существительное'],
#  'малый': ['прилагательное', 'существительное'],
#  'марш': ['междометие', 'существительное'],
#  'мастеровой': ['прилагательное', 'существительное'],
#  'мертвый': ['прилагательное', 'существительное'],
#  'милый': ['прилагательное', 'существительное'],
#  'мимо': ['наречие', 'предлог'],
#  'минимум': ['наречие', 'существительное'],
#  'минус': ['союз', 'предлог', 'существительное'],
#  'мм': ['междометие', 'имя собственное'],
#  'много': ['наречие', 'местоименное наречие', 'количественное числительное'],
#  'много-много': ['наречие', 'количественное числительное'],
#  'многовато': ['наречие', 'количественное числительное'],
#  'мол': ['частица', 'существительное'],
#  'мочь': ['существительное', 'глагол'],
#  'на': ['частица', 'предлог'],
#  'надо': ['наречие', 'предлог'],
#  'накануне': ['наречие', 'предлог'],
#  'напасть': ['существительное', 'глагол'],
#  'направляющий': ['прилагательное', 'существительное'],
#  'напротив': ['наречие', 'предлог'],
#  'начинающий': ['прилагательное', 'существительное'],
#  'небось': ['наречие', 'частица'],
#  'неверный': ['прилагательное', 'существительное'],
#  'неверующий': ['прилагательное', 'существительное'],
#  'невыездной': ['прилагательное', 'существительное'],
#  'неграмотный': ['прилагательное', 'существительное'],
#  'нежить': ['существительное', 'глагол'],
#  'неизвестно': ['наречие', 'частица'],
#  'немало': ['наречие', 'количественное числительное'],
#  'немного': ['наречие', 'количественное числительное'],
#  'немножко': ['наречие', 'количественное числительное'],
#  'неохота': ['наречие', 'существительное'],
#  'непосвященный': ['прилагательное', 'существительное'],
#  'несколько': ['наречие', 'количественное числительное'],
#  'нет': ['наречие', 'частица', 'существительное'],
#  'нет-нет': ['наречие', 'частица'],
#  'ни': ['союз', 'частица'],
#  'ниже': ['наречие', 'предлог'],
#  'никак': ['местоименное наречие', 'частица'],
#  'ниче': ['частица', 'местоимение-существительное'],
#  'ништяк': ['частица', 'существительное'],
#  'нищий': ['прилагательное', 'существительное'],
#  'но': ['союз', 'существительное'],
#  'новорожденный': ['прилагательное', 'существительное'],
#  'ну-у': ['междометие', 'частица'],
#  'о': ['междометие', 'предлог'],
#  'ого-го': ['наречие', 'междометие'],
#  'одержимый': ['прилагательное', 'существительное'],
#  'один': ['порядковое числительное', 'местоимение-прилагательное'],
#  'однако': ['наречие', 'союз'],
#  'ок': ['наречие', 'частица'],
#  'около': ['наречие', 'предлог'],
#  'окрест': ['наречие', 'предлог'],
#  'отделенный': ['прилагательное', 'существительное'],
#  'относительно': ['наречие', 'предлог'],
#  'ото': ['междометие', 'предлог'],
#  'отсутствующий': ['прилагательное', 'существительное'],
#  'охота': ['наречие', 'существительное'],
#  'пардон': ['междометие', 'существительное'],
#  'пас': ['наречие', 'существительное'],
#  'пасть': ['существительное', 'глагол'],
#  'певчий': ['прилагательное', 'существительное'],
#  'перед': ['предлог', 'существительное'],
#  'печь': ['существительное', 'глагол'],
#  'пи': ['междометие', 'существительное'],
#  'пик': ['прилагательное', 'существительное'],
#  'пленный': ['прилагательное', 'существительное'],
#  'плюс': ['союз', 'существительное'],
#  'погибший': ['прилагательное', 'существительное'],
#  'под': ['предлог', 'существительное'],
#  'подать': ['существительное', 'глагол'],
#  'поди': ['наречие', 'междометие'],
#  'подопечный': ['прилагательное', 'существительное'],
#  'подручный': ['прилагательное', 'существительное'],
#  'подряд': ['наречие', 'существительное'],
#  'подчиненный': ['прилагательное', 'существительное'],
#  'пожарный': ['прилагательное', 'существительное'],
#  'пожилой': ['прилагательное', 'существительное'],
#  'позади': ['наречие', 'предлог'],
#  'пока': ['наречие', 'союз', 'частица'],
#  'покамест': ['наречие', 'союз'],
#  'покойный': ['прилагательное', 'существительное'],
#  'покуда': ['наречие', 'союз'],
#  'пол': ['количественное числительное', 'существительное'],
#  'полицейский': ['прилагательное', 'существительное'],
#  'половой': ['прилагательное', 'существительное'],
#  'помешанный': ['прилагательное', 'существительное'],
#  'поперек': ['наречие', 'предлог'],
#  'пора': ['наречие', 'существительное'],
#  'посередине': ['наречие', 'предлог'],
#  'после': ['наречие', 'предлог'],
#  'посредине': ['наречие', 'предлог'],
#  'постовой': ['прилагательное', 'существительное'],
#  'постольку': ['местоименное наречие', 'союз'],
#  'почивший': ['прилагательное', 'существительное'],
#  'правда': ['наречие', 'частица', 'существительное'],
#  'право': ['наречие', 'существительное'],
#  'правоверный': ['прилагательное', 'существительное'],
#  'православный': ['прилагательное', 'существительное'],
#  'правый': ['прилагательное', 'существительное'],
#  'прежде': ['наречие', 'предлог'],
#  'приближенный': ['прилагательное', 'существительное'],
#  'придворный': ['прилагательное', 'существительное'],
#  'приезжий': ['прилагательное', 'существительное'],
#  'припадочный': ['прилагательное', 'существительное'],
#  'присутствующий': ['прилагательное', 'существительное'],
#  'присяжный': ['прилагательное', 'существительное'],
#  'проездной': ['прилагательное', 'существительное'],
#  'проезжий': ['прилагательное', 'существительное'],
#  'пропасть': ['существительное', 'глагол'],
#  'просто': ['наречие', 'частица'],
#  'простой': ['прилагательное', 'существительное'],
#  'против': ['наречие', 'предлог'],
#  'прохожий': ['прилагательное', 'существительное'],
#  'прямо': ['наречие', 'частица'],
#  'пускай': ['союз', 'частица'],
#  'пусть': ['союз', 'частица'],
#  'пьяный': ['прилагательное', 'существительное'],
#  'рабочий': ['прилагательное', 'существительное'],
#  'равно': ['наречие', 'союз'],
#  'раз': ['наречие', 'союз', 'междометие', 'существительное'],
#  'разве': ['союз', 'частица'],
#  'раненый': ['прилагательное', 'существительное'],
#  'ровно': ['наречие', 'союз', 'частица'],
#  'ротный': ['прилагательное', 'существительное'],
#  'рулевой': ['прилагательное', 'существительное'],
#  'русский': ['прилагательное', 'существительное'],
#  'рыжий': ['прилагательное', 'существительное'],
#  'рядовой': ['прилагательное', 'существительное'],
#  'ряженый': ['прилагательное', 'существительное'],
#  'с': ['частица', 'предлог'],
#  'светлейший': ['прилагательное', 'существительное'],
#  'свыше': ['наречие', 'предлог'],
#  'связной': ['прилагательное', 'существительное'],
#  'святой': ['прилагательное', 'существительное'],
#  'се': ['частица', 'местоимение-существительное'],
#  'сзади': ['наречие', 'предлог'],
#  'сколько': ['местоименное наречие', 'союз', 'количественное числительное'],
#  'слабоумный': ['прилагательное', 'существительное'],
#  'слепой': ['прилагательное', 'существительное'],
#  'словно': ['союз', 'частица'],
#  'служащий': ['прилагательное', 'существительное'],
#  'служивый': ['прилагательное', 'существительное'],
#  'смертный': ['прилагательное', 'существительное'],
#  'собственно': ['наречие', 'частица'],
#  'согласно': ['наречие', 'предлог'],
#  'согласный': ['прилагательное', 'существительное'],
#  'соло': ['наречие', 'существительное'],
#  'соответственно': ['наречие', 'союз', 'предлог'],
#  'сорри': ['междометие', 'частица'],
#  'спасибо': ['наречие', 'частица', 'существительное'],
#  'спящий': ['прилагательное', 'существительное'],
#  'сродни': ['наречие', 'предлог'],
#  'ссыльный': ['прилагательное', 'существительное'],
#  'старший': ['прилагательное', 'существительное'],
#  'стать': ['существительное', 'глагол'],
#  'столько': ['местоименное наречие', 'количественное числительное'],
#  'стоп': ['прилагательное', 'междометие'],
#  'страсть': ['наречие', 'существительное'],
#  'стук': ['междометие', 'существительное'],
#  'сумасшедший': ['прилагательное', 'существительное'],
#  'супер': ['прилагательное', 'наречие', 'междометие'],
#  'счастливо': ['наречие', 'частица'],
#  'так': ['местоименное наречие', 'частица'],
#  'также': ['наречие', 'союз'],
#  'там': ['местоименное наречие', 'частица'],
#  'танин': ['прилагательное', 'существительное'],
#  'тепло': ['наречие', 'существительное'],
#  'течь': ['существительное', 'глагол'],
#  'типа': ['частица', 'предлог'],
#  'то': ['союз', 'частица', 'местоимение-существительное'],
#  'то-то': ['наречие', 'частица', 'местоимение-существительное'],
#  'тож': ['наречие', 'частица'],
#  'тока': ['союз', 'частица'],
#  'только': ['союз', 'частица'],
#  'топ': ['междометие', 'существительное'],
#  'точно': ['наречие', 'союз', 'частица'],
#  'трудящийся': ['прилагательное', 'существительное'],
#  'тяжелобольной': ['прилагательное', 'существительное'],
#  'у': ['междометие', 'предлог'],
#  'убитый': ['прилагательное', 'существительное'],
#  'убогий': ['прилагательное', 'существительное'],
#  'угодно': ['наречие', 'частица'],
#  'уж': ['наречие', 'частица', 'существительное'],
#  'умерший': ['прилагательное', 'существительное'],
#  'умирающий': ['прилагательное', 'существительное'],
#  'уполномоченный': ['прилагательное', 'существительное'],
#  'управляющий': ['прилагательное', 'существительное'],
#  'усе': ['местоименное наречие', 'местоимение-существительное'],
#  'усопший': ['прилагательное', 'существительное'],
#  'участковый': ['прилагательное', 'существительное'],
#  'учащийся': ['прилагательное', 'существительное'],
#  'ученый': ['прилагательное', 'существительное'],
#  'фиг': ['наречие', 'существительное'],
#  'флотский': ['прилагательное', 'существительное'],
#  'фон': ['частица', 'существительное'],
#  'хаки': ['прилагательное', 'существительное'],
#  'хана': ['наречие', 'существительное'],
#  'хвать': ['наречие', 'междометие'],
#  'хорошо': ['наречие', 'частица'],
#  'хоть': ['союз', 'частица'],
#  'хотя': ['союз', 'частица'],
#  'хромой': ['прилагательное', 'существительное'],
#  'худо': ['наречие', 'существительное'],
#  'центровой': ['прилагательное', 'существительное'],
#  'чай': ['частица', 'существительное'],
#  'часовой': ['прилагательное', 'существительное'],
#  'че': ['местоименное наречие', 'местоимение-существительное'],
#  'чего-то': ['местоименное наречие', 'местоимение-существительное'],
#  'честь': ['существительное', 'глагол'],
#  'чо': ['частица', 'местоимение-существительное'],
#  'что': ['местоименное наречие',
#   'союз',
#   'частица',
#   'местоимение-существительное'],
#  'что-то': ['местоименное наречие', 'местоимение-существительное'],
#  'чужой': ['прилагательное', 'существительное'],
#  'чуть': ['наречие', 'союз'],
#  'штатский': ['прилагательное', 'существительное'],
#  'што': ['союз', 'местоимение-существительное'],
#  'штрафной': ['прилагательное', 'существительное'],
#  'щелк': ['междометие', 'существительное'],
#  'экстра': ['прилагательное', 'существительное'],
#  'эль': ['частица', 'существительное'],
#  'это': ['частица', 'местоимение-существительное'],
#  'юродивый': ['прилагательное', 'существительное'],
#  'якобы': ['союз', 'частица']}

# %% [markdown]
# Итак, мы нашли 378 омонимов в частотном словаре. В полученном словаре омонимов отражается интересный лингвистический факт: в русском языке (и не только в русском, кстати) довольно часто прилагательное "превращается" в существительное, когда существительное как бы подразумевается, потому что другого не может быть. Например, "верующий человек" и просто "верующий". В первом случае "верующий" - это прилагательное, а во втором - существительное (подразумевается, что верующий - это, конечно, человек, а не зверь или предмет).
